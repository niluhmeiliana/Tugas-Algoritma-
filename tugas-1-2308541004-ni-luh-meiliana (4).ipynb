# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
Harga_bensin = input('berapakah harga bensin per liternya?')
Waktu = input('dalam seminggu berapa kali membeli bensin?')
Total_membeli_bensin = int(Harga_bensin) * int(Waktu)
print("total membeli bensin dalam seminggu adalah Rp "+ str(Total_membeli_bensin))
# Out:
# berapakah harga bensin per liternya? 10000
# dalam seminggu berapa kali membeli bensin? 2
# total membeli bensin dalam seminggu adalah Rp 20000

# %%
waktu_kegiatan = "Sabtu,16 maret 2024"
judul_kegiatan = "MATCA 2024"
kegiatan = input("Apa saja yang anda lakukan saat, " + judul_kegiatan)
perasaan = input("bagaimana setelah mengikuti, " + judul_kegiatan)
print(waktu_kegiatan + judul_kegiatan + kegiatan + perasaan)
# Out:
# Apa saja yang anda lakukan saat, MATCA 2024 Menanam bibit mangrove dan berkeliling dengan kano
# bagaimana setelah mengikuti, MATCA 2024 sangat senang
# Sabtu,16 maret 2024MATCA 2024Menanam bibit mangrove dan berkeliling dengan kanosangat senang

# %%
berat_badan_anak_A = input('Masukkan berat badan')
berat_badan_anak_B = input('Masukkan berat badan')
jumlah = float(berat_badan_anak_A) + float(berat_badan_anak_B) 
print("jumlah berat badan kedua anak tersebut adalah "+ str(jumlah))
# Out:
# Masukkan berat badan 20
# Masukkan berat badan 23
# jumlah berat badan kedua anak tersebut adalah 43.0

# %%
Universitas = input('dimana anda berkuliah?')
Tempat = input('dimana anda tinggal')
Jarak = input('berapa jarak anda kekampus dari rumah?')
waktu = input('berapa lama waktu yang anda habiskan?')
print(Universitas + Tempat + Jarak + waktu + "Semangat kuliah nya")
# Out:
# dimana anda berkuliah? Universitas Udayana
# dimana anda tinggal Jl.Raya Sading
# berapa jarak anda kekampus dari rumah? 25 km
# berapa lama waktu yang anda habiskan? 1,5 jam
# Universitas UdayanaJl.Raya Sading25 km1,5 jamSemangat kuliah nya

# %%
harga_beras_kg = 17000
harga_buah_apel_kg = 45000
harga_daging_kg = 35000
print(harga_beras_kg + harga_buah_apel_kg + harga_daging_kg)
# Out:
# 97000

# %%
tinggi_badan_diva_cm = 156
tinggi_badan_wina_cm = 150
berat_badan_artika_kg = 50
pertanyaan =('berapakah total keseluruhan antara tinggi badan diva dikurangi tinggi badan wina ditambah berat badan artika?')
hasil = int(tinggi_badan_diva_cm) - int(tinggi_badan_wina_cm) + int(berat_badan_artika_kg)
print('selisih tinggi badan diva dan wina ditambah berat badan artika' + str(hasil))
# Out:
# selisih tinggi badan diva dan wina ditambah berat badan artika56

# %%
murid_kelas_1 = 30
murid_kelas_3 = 45
murid_kelas_5 = 40
jumlah = float(murid_kelas_1) + float(murid_kelas_3) + float(murid_kelas_5)
print('jumlah seluruh murid SD adalah' + str(jumlah))
# Out:
# jumlah seluruh murid SD adalah115.0
