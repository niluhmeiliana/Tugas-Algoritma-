# %%
# Persamaan garis yang melewati 2 titik
# Garis pertama melewati (p,q) dan (r,s)
# Garis kedua melewati (t,u) dan (v,w)
# Terdapat 3 kemungkinan dari kedua persamaan garis ini:
# 1. Terdapat perpotongan di satu titik (gradien kedua garis tidak sama)
# 2. Terdapat tak berhingga banyaknya solusi (kedua garis berhimpitan) (kedua garis sejajar)
# 3. Tidak terdapat perpotongan garis (tidak terdapat solusi) (kedua garis sejajar)

import numpy as np
import matplotlib.pyplot as plt

p_04 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
q_04 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
r_04 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
s_04 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

t_04 = float(input("Nilai x dari titik pertama dari garis kedua adalah "))
u_04 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
v_04 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
w_04 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

m_1_04 = (s_04-q_04)/(r_04-p_04) # Gradien garis pertama
m_2_04 = (w_04-u_04)/(v_04-t_04) # Gradien garis kedua

# Persamaan garis pertama adalah y=m_1_04(x-p_04)+q_04=m_1_04x-m_1_04p_04+q_04
# Persamaan garis kedua adalah y=m_2_04(x-t_04)+u_04=m_2_04x-m_2_04t_04+u_04

c_1_04 = -m_1_04*p_04+q_04 # Titik potong garis pertama terhadap sumbu y
c_2_04 = -m_2_04*t_04+u_04 # titik potong garis kedua terhadap sumbu y garis kedua

print("Persamaan garis pertama adalah y={}x+{}".format(m_1_04,c_1_04))
print("Persamaan garis kedua adalah y={}x+{}".format(m_2_04,c_2_04))

if m_1_04==m_2_04:
    #print("Kedua garis sejajar sehingga kemungkinannya adalah tidak terdapat solusi atau terdapat tak berhingga banyaknya solusi")
    if c_1_04 == c_2_04:
        print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_04*(x-p_04)+q_04,color='pink')
        plt.plot(x,m_2_04*(x-t_04)+u_04,color='blue')
        plt.show()
    else:
        print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_04*(x-p_04)+q_04,color='pink')
        plt.plot(x,m_2_04*(x-t_04)+u_04,color='blue')
        plt.show()
else:
    print("Akan terdapat satu titik potong")
    tp_x = (-m_2_04*t_04+u_04+m_1_04*p_04-q_04)/(m_1_04-m_2_04)
    tp_y = m_1_04*(tp_x-p_04)+q_04
    print("Titik potong kedua garis adalah ({},{})".format(tp_x,tp_y))

    x=np.linspace(tp_x-5,tp_x+5,100)
    plt.plot(x,m_1_04*(x-p_04)+q_04,color='pink')
    plt.plot(x,m_2_04*(x-t_04)+u_04,color='blue')
    plt.axvline(x=0,color='grey')
    plt.axhline(y=0,color='grey')
    plt.show()
# Out:
# Nilai x dari titik pertama dari garis pertama adalah 2
# Nilai y dari titik pertama dari garis pertama adalah 2
# Nilai x dari titik kedua dari garis pertama adalah 4
# Nilai y dari titik kedua dari garis pertama adalah 4
# Nilai x dari titik pertama dari garis kedua adalah 6
# Nilai y dari titik pertama dari garis kedua adalah 6
# Nilai x dari titik kedua dari garis kedua adalah 8
# Nilai y dari titik kedua dari garis kedua adalah 8
# Persamaan garis pertama adalah y=1.0x+0.0
# Persamaan garis kedua adalah y=1.0x+0.0
# Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi

# %%
# Persamaan garis yang melewati 2 titik
# Garis pertama melewati (p,q) dan (r,s)
# Garis kedua melewati (t,u) dan (v,w)
# Terdapat 3 kemungkinan dari kedua persamaan garis ini:
# 1. Terdapat perpotongan di satu titik (gradien kedua garis tidak sama)
# 2. Terdapat tak berhingga banyaknya solusi (kedua garis berhimpitan) (kedua garis sejajar)
# 3. Tidak terdapat perpotongan garis (tidak terdapat solusi) (kedua garis sejajar)

import numpy as np
import matplotlib.pyplot as plt

p_04 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
q_04 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
r_04 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
s_04 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

t_04 = float(input("Nilai x dari titik pertama dari garis kedua adalah "))
u_04 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
v_04 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
w_04 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

m_1_04 = (s_04-q_04)/(r_04-p_04) # Gradien garis pertama
m_2_04 = (w_04-u_04)/(v_04-t_04) # Gradien garis kedua

# Persamaan garis pertama adalah y=m_1_04(x-p_04)+q_04=m_1_04x-m_1_04p_04+q_04
# Persamaan garis kedua adalah y=m_2_04(x-t_04)+u_04=m_2_04x-m_2_04t_04+u_04

c_1_04 = -m_1_04*p_04+q_04 # Titik potong garis pertama terhadap sumbu y
c_2_04 = -m_2_04*t_04+u_04 # titik potong garis kedua terhadap sumbu y garis kedua

print("Persamaan garis pertama adalah y={}x+{}".format(m_1_04,c_1_04))
print("Persamaan garis kedua adalah y={}x+{}".format(m_2_04,c_2_04))

if m_1_04==m_2_04:
    #print("Kedua garis sejajar sehingga kemungkinannya adalah tidak terdapat solusi atau terdapat tak berhingga banyaknya solusi")
    if c_1_04 == c_2_04:
        print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_04*(x-p_04)+q_04,color='yellow')
        plt.plot(x,m_2_04*(x-t_04)+u_04,color='green')
        plt.show()
    else:
        print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_04*(x-p_04)+q_04,color='yellow')
        plt.plot(x,m_2_04*(x-t_04)+u_04,color='green')
        plt.show()
else:
    print("Akan terdapat satu titik potong")
    tp_x_04 = (-m_2_04*t_04+u_04+m_1_04*p_04-q_04)/(m_1_04-m_2_04)
    tp_y_04 = m_1_04*(tp_x-p_04)+q_04
    print("Titik potong kedua garis adalah ({},{})".format(tp_x_04,tp_y_04))

    x=np.linspace(tp_x-5,tp_x+5,100)
    plt.plot(x,m_1_04*(x-p_04)+q_04,color='yellow')
    plt.plot(x,m_2_04*(x-t_04)+u_04,color='green')
    plt.axvline(x=0,color='grey')
    plt.axhline(y=0,color='grey')
    plt.show()
# Out:
# Nilai x dari titik pertama dari garis pertama adalah 2
# Nilai y dari titik pertama dari garis pertama adalah 2
# Nilai x dari titik kedua dari garis pertama adalah 4
# Nilai y dari titik kedua dari garis pertama adalah 4
# Nilai x dari titik pertama dari garis kedua adalah -2
# Nilai y dari titik pertama dari garis kedua adalah 0
# Nilai x dari titik kedua dari garis kedua adalah 0
# Nilai y dari titik kedua dari garis kedua adalah 2
# Persamaan garis pertama adalah y=1.0x+0.0
# Persamaan garis kedua adalah y=1.0x+2.0
# Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.

# %%
# Persamaan garis yang melewati 2 titik
# Garis pertama melewati (p,q) dan (r,s)
# Garis kedua melewati (t,u) dan (v,w)
# Terdapat 3 kemungkinan dari kedua persamaan garis ini:
# 1. Terdapat perpotongan di satu titik (gradien kedua garis tidak sama)
# 2. Terdapat tak berhingga banyaknya solusi (kedua garis berhimpitan) (kedua garis sejajar)
# 3. Tidak terdapat perpotongan garis (tidak terdapat solusi) (kedua garis sejajar)

import numpy as np
import matplotlib.pyplot as plt

p_04 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
q_04 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
r_04 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
s_04 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

t_04= float(input("Nilai x dari titik pertama dari garis kedua adalah "))
u_04 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
v_04 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
w_04 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

m_1_04 = (s_04-q_04)/(r_04-p_04) # Gradien garis pertama
m_2_04 = (w_04-u_04)/(v_04-t_04) # Gradien garis kedua

# Persamaan garis pertama adalah y=m_1_04(x-p_04)+q_04=m_1_04x-m_1_04p_04+q_04
# Persamaan garis kedua adalah y=m_2_04(x-t_04)+u_04=m_2_04x-m_2_04t_04+u_04

c_1_04 = -m_1_04*p_04+q_04 # Titik potong garis pertama terhadap sumbu y
c_2_04 = -m_2_04*t_04+u_04 # titik potong garis kedua terhadap sumbu y garis kedua

print("Persamaan garis pertama adalah y={}x+{}".format(m_1_04,c_1_04))
print("Persamaan garis kedua adalah y={}x+{}".format(m_2_04,c_2_04))

if m_1_04==m_2_04:
    #print("Kedua garis sejajar sehingga kemungkinannya adalah tidak terdapat solusi atau terdapat tak berhingga banyaknya solusi")
    if c_1_04 == c_2_04:
        print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_04*(x-p_4)+q_04,color='purple')
        plt.plot(x,m_2_04*(x-t_04)+u_04,color='black')
        plt.show()
    else:
        print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_04*(x-p_04)+q_04,color='purple')
        plt.plot(x,m_2_04*(x-t_04)+u_04,color='black')
        plt.show()
else:
    print("Akan terdapat satu titik potong")
    tp_x_04 = (-m_2_04*t_04+u_04+m_1_04*p_04-q_04)/(m_1_04-m_2_04)
    tp_y_04 = m_1_04*(tp_x_04-p_04)+q_04
    print("Titik potong kedua garis adalah ({},{})".format(tp_x_04,tp_y_04))

    x=np.linspace(tp_x_04-5,tp_x_04+5,100)
    plt.plot(x,m_1_04*(x-p_04)+q_04,color='purple')
    plt.plot(x,m_2_04*(x-t_04)+u_04,color='black')
    plt.axvline(x=0,color='grey')
    plt.axhline(y=0,color='grey')
    plt.show()
# Out:
# Nilai x dari titik pertama dari garis pertama adalah 3
# Nilai y dari titik pertama dari garis pertama adalah 3
# Nilai x dari titik kedua dari garis pertama adalah 6
# Nilai y dari titik kedua dari garis pertama adalah 6
# Nilai x dari titik pertama dari garis kedua adalah 3
# Nilai y dari titik pertama dari garis kedua adalah 6
# Nilai x dari titik kedua dari garis kedua adalah 6
# Nilai y dari titik kedua dari garis kedua adalah 6
# Persamaan garis pertama adalah y=1.0x+0.0
# Persamaan garis kedua adalah y=0.0x+6.0
# Akan terdapat satu titik potong
# Titik potong kedua garis adalah (6.0,6.0)

# %%
# Memanggil numpy
import numpy as np
# Memanggil matplotlib.pyplot
import matplotlib.pyplot as plt


print('===============Mencari solusi dari bentuk persamaan garis jika diketahui gradien dan titik yang dilewati===============')

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (p,q)
m1_04 = float(input("Masukkan gradien dari garis pertama: "))
p_04 = float(input("Msukkan nilai x dari titik yang dilewati oleh garis pertama: "))
q_04 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis pertama: "))

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (r,s)
m2_04 = float(input("Masukkan gradien dari garis kedua: "))
r_04 = float(input("Masukkan nilai x dari titik yang dilewati oleh garis kedua: "))
s_04 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis kedua: "))

# Menghitung konstanta dari masing-masing persamaan garis
c1_04 = -m1_04*p_04+q_04
c2_04 = -m2_04*r_04+s_04

    # Memeriksa apakah kedua garis sejajar atau tidak
if m1_04 == m2_04:
      # print("Kedua garis sejajar ")
        if c1_04 == c2_04:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Plotting the lines
        x = np.linspace(-10, 10, 400)
        y1_04 = m1_04*(x-p_04)+ q_04
        y2_04 = m2_04*(x-r_04) + s_04
        plt.plot(x, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='purple')
        plt.plot(x, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='blue')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
else:
        # Menghitung titik potong dari kedua garis
        x_intersect = (c2_04 - c1_04) / (m1_04 - m2_04)
        y_intersect = m1_04 * (x_intersect - a_04) + b_04
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(x_intersect, y_intersect))

        # Plotting the lines
        x = np.linspace(x_intersect-10, x_intersect+10, 400)
        y1_04 = m1_04*(x-p_04)+q_04
        y2_04 = m2_04*(x-r_04)+s_04
        plt.plot(x, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='purple')
        plt.plot(x, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='blue')
        plt.scatter(x_intersect, y_intersect, color='red', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
print('==========================================Terima Kasih==========================================')
# Out:
# ===============Mencari solusi dari bentuk persamaan garis jika diketahui gradien dan titik yang dilewati===============
# Masukkan gradien dari garis pertama: 1
# Msukkan nilai x dari titik yang dilewati oleh garis pertama: 3
# Masukkan nilai y dari titik yang dilewati oleh garis pertama: 4
# Masukkan gradien dari garis kedua: 1
# Masukkan nilai x dari titik yang dilewati oleh garis kedua: 2
# Masukkan nilai y dari titik yang dilewati oleh garis kedua: 0
# Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.
# ==========================================Terima Kasih==========================================

# %%
# Memanggil numpy
import numpy as np
# Memanggil matplotlib.pyplot
import matplotlib.pyplot as plt


print('===============Mencari solusi dari bentuk persamaan garis jika diketahui gradien dan titik yang dilewati===============')

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (p,q)
m1_04 = float(input("Masukkan gradien dari garis pertama: "))
p_04 = float(input("Msukkan nilai x dari titik yang dilewati oleh garis pertama: "))
q_04 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis pertama: "))

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (r,s)
m2_04 = float(input("Masukkan gradien dari garis kedua: "))
r_04 = float(input("Masukkan nilai x dari titik yang dilewati oleh garis kedua: "))
s_04 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis kedua: "))

# Menghitung konstanta dari masing-masing persamaan garis
c1_04 = -m1_04*p_04+q_04
c2_04 = -m2_04*r_04+s_04

    # Memeriksa apakah kedua garis sejajar atau tidak
if m1_04 == m2_04:
      # print("Kedua garis sejajar ")
        if c1_04 == c2_04:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Plotting the lines
        x = np.linspace(-10, 10, 400)
        y1_04 = m1_04*(x-p_04)+ q_04
        y2_04 = m2_04*(x-r_04) + s_04
        plt.plot(x, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='yellow')
        plt.plot(x, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='blue')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
else:
        # Menghitung titik potong dari kedua garis
        x_intersect = (c2_04 - c1_04) / (m1_04 - m2_04)
        y_intersect = m1_04 * (x_intersect - p_04) + q_04
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(x_intersect, y_intersect))

        # Plotting the lines
        x = np.linspace(x_intersect-10, x_intersect+10, 400)
        y1_04 = m1_04*(x-p_04)+q_04
        y2_04 = m2_04*(x-r_04)+s_04
        plt.plot(x, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='yellow')
        plt.plot(x, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='blue')
        plt.scatter(x_intersect, y_intersect, color='red', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
print('==========================================Terima Kasih==========================================')
# Out:
# ===============Mencari solusi dari bentuk persamaan garis jika diketahui gradien dan titik yang dilewati===============
# Masukkan gradien dari garis pertama: 2
# Msukkan nilai x dari titik yang dilewati oleh garis pertama: 1
# Masukkan nilai y dari titik yang dilewati oleh garis pertama: -2
# Masukkan gradien dari garis kedua: 4
# Masukkan nilai x dari titik yang dilewati oleh garis kedua: 1
# Masukkan nilai y dari titik yang dilewati oleh garis kedua: -4
# Titik potong kedua garis adalah (2.000,0.000)
# ==========================================Terima Kasih==========================================

# %%
# Memanggil numpy
import numpy as np
# Memanggil matplotlib.pyplot
import matplotlib.pyplot as plt


print('===============Mencari solusi dari bentuk persamaan garis jika diketahui gradien dan titik yang dilewati===============')

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (p,q)
m1_04 = float(input("Masukkan gradien dari garis pertama: "))
p_04 = float(input("Masukkan nilai x dari titik yang dilewati oleh garis pertama: "))
q_04 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis pertama: "))

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (r,s)
m2_04 = float(input("Masukkan gradien dari garis kedua: "))
r_04 = float(input("Masukkan nilai x dari titik yang dilewati oleh garis kedua: "))
s_04 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis kedua: "))

# Menghitung konstanta dari masing-masing persamaan garis
c1_04 = -m1_04*p_04+q_04
c2_04 = -m2_04*r_04+s_04

    # Memeriksa apakah kedua garis sejajar atau tidak
if m1_04 == m2_04:
      # print("Kedua garis sejajar ")
        if c1_04 == c2_04:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Plotting the lines
        x = np.linspace(-10, 10, 400)
        y1_04 = m1_04*(x-p_04)+ q_04
        y2_04 = m2_04*(x-r_04) + s_04
        plt.plot(x, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='brown')
        plt.plot(x, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='red')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
else:
        # Menghitung titik potong dari kedua garis
        x_intersect = (c2_04 - c1_04) / (m1_04 - m2_04)
        y_intersect = m1_04 * (x_intersect - p_04) + q_04
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(x_intersect, y_intersect))

        # Plotting the lines
        x = np.linspace(x_intersect-10, x_intersect+10, 400)
        y1_04 = m1_04*(x-p_04)+q_04
        y2_04 = m2_04*(x-r_04)+s_04
        plt.plot(x, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='brown')
        plt.plot(x, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='red')
        plt.scatter(x_intersect, y_intersect, color='yellwo', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
print('==========================================Terima Kasih==========================================')
# Out:
# ===============Mencari solusi dari bentuk persamaan garis jika diketahui gradien dan titik yang dilewati===============
# Masukkan gradien dari garis pertama: 4
# Masukkan nilai x dari titik yang dilewati oleh garis pertama: 1
# Masukkan nilai y dari titik yang dilewati oleh garis pertama: 5
# Masukkan gradien dari garis kedua: 4
# Masukkan nilai x dari titik yang dilewati oleh garis kedua: 1
# Masukkan nilai y dari titik yang dilewati oleh garis kedua: 5
# Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi
# ==========================================Terima Kasih==========================================

# %%
import numpy as np
import matplotlib.pyplot as plt

kasus = float(input("Kasus berapakah yang akan dikerjakan? "))

if kasus == 1:
    # Masukkan titik garis pertama (a,b) dan (c,d)
    p_04 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
    q_04 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
    r_04 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
    s_04 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

    # Masukkan titik garis kedua (e,f) dan (g,h)
    t_04 = float(input("Nilai x dari titik pertama dari garis kedua adalah "))
    u_04 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
    v_04 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
    w_04 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

    # Gradien garis pertama
    m1_04 = (s_04 - q_04) / (r_04 - p_04)
    # Gradien garis kedua
    m2_04 = (w_04 - u_04) / (v_04 - t_04)

    # Persamaan garis pertama adalah y=m1(x-a)+b => m1*x-m1*a+b
    # Persamaan garis kedua adalah y=m2(x-e)+f => m2*x-m2*e+f

    # Titik potong garis pertama terhadap sumbu y
    c1_04 = -m1_04 * p_04 + q_04
    # Titik potong garis kedua terhadap sumbu y garis kedua
    c2_04 = -m2_04 * t_04 + u_04

    print("Persamaan garis pertama adalah y={}x+{}".format(m1_04, c1_04))
    print("Persamaan garis kedua adalah y={}x+{}".format(m2_04, c2_04))

    if m1_04 == m2_04:
        # print("Kedua garis sejajar sehingga kemungkinan yang terjadi adalah tidak terdapat solusi atau terdapat tidak berhingga banyaknya solusi")
        if c1_04 == c2_04:
            print("Kedua garis akan berhimpitan sehingga terdapat tidak berhingga banyaknya solusi")
            x_04 = np.linspace(-9, 9, 100)
            plt.plot(x_04, m1_04 * (x_04 - p_04) + q_04, color='pink')
            plt.plot(x_04, m2_04 * (x_04 - t_04) + u_04, color='yellow')
            plt.show()
        else:
            print("Kedua garis tidak akan berpotongan, sehingga tidak akan terdapat solusi")
            x_04 = np.linspace(-10, 10, 100)
            plt.plot(x_04, m1_04 * (x_04 - p_04) + q_04, color='green')
            plt.plot(x_04, m2_04 * (x_04 - t_04) + u_04, color='red')
            plt.show()
    else:
        print("Terdapat satu titik potong")
        tp_x_04 = (-m2_04 * t_04 + u_04 + m1_04 * p_04 - q_04) / (m1_04 - m2_04)
        tp_y_04 = m1_04 * (tp_x_04 - p_04) + q_04
        print("Titik potong kedua garis yaitu ({},{})".format(tp_x_04, tp_y_04))

        x_04 = np.linspace(tp_x_04 - 10, tp_x_04 + 10, 100)
        plt.plot(x_04, m1_04 * (x_4 - p_04) + q_04, color='red')
        plt.plot(x_04, m2_04 * (x_04 - t_04) + u_04, color='green')
        plt.plot(tp_x_04, tp_y_04, color='black', marker='o', markersize=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.show()

elif kasus == 2:
    # Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (a,b)
    m1_04 = float(input("Gradien dari garis pertama adalah: "))
    p_04 = float(input("Nilai x dari titik yang dilewati oleh garis pertama adalah: "))
    q_04 = float(input("Nilai y dari titik yang dilewati oleh garis pertama adalah: "))

    # Masukkan nilai gradien persamaan garis kedua dan titik yang diketahui (c,d)
    m2_04 = float(input("Gradien dari garis kedua adalah: "))
    r_04 = float(input("Nilai x dari titik yang dilewati oleh garis kedua adalah: "))
    s_04 = float(input("Nilai y dari titik yang dilewati oleh garis kedua adalah: "))

    # Menghitung konstanta dari masing-masing persamaan garis
    c1_04 = -m1_04 * p_04 + q_04
    c2_04 = -m2_04 * r_04 + s_04

    # Memeriksa apakah kedua garis sejajar atau tidak
    if m1_04 == m2_04:
        # print("Kedua garis sejajar ")
        if c1_04 == c2_04:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Format garis
        x_04 = np.linspace(-10, 10, 400)
        y1_04 = m1_04 * (x_04 - p_04) + q_04
        y2_04 = m2_04 * (x_04 - r_04) + s_04
        plt.plot(x_04, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='green')
        plt.plot(x_04, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='red')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
    else:
        # Menghitung titik potong dari kedua garis
        tp_x_04 = (c2_04 - c1_04) / (m1_04 - m2_04)
        tp_y_04= m1_04 * (x_intersect - p_04) + q_04
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x_04, tp_y_04))

        # Format garis
        x_04 = np.linspace(tp_x_04 - 10, tp_x_04 + 10, 400)
        y1_04 = m1_04 * (x_04 - p_04) + q_04
        y2_04 = m2_04 * (x_04 - r_04) + s_04
        plt.plot(x_04, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='red')
        plt.plot(x_04, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='blue')
        plt.scatter(tp_x_04, tp_y_04, color='green', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()

elif kasus == 3:
    # Masukkan nilai koefisien dan konstanta
    print("Garis pertama yang memenuhi persamaan berbentuk ax + by = c ")
    p_04 = float(input("Koefisien dari x pada garis pertama adalah "))
    q_04 = float(input("Koefisien dari y pada garis pertama adalah "))
    r_04 = float(input("Konstanta dari garis pertama adalah "))

    print("Garis kedua yang memenuhi persamaan berbentuk dx + ey = f ")
    s_04 = float(input("Koefisien dari x pada garis kedua adalah "))
    t_04 = float(input("Koefisien dari y pada garis kedua adalah "))
    u_04 = float(input("Konstanta dari garis kedua adalah "))
    # Menghitung determinan utama
    D_04 = p_04*t_04 - q_04*s_04

    if D_04 == 0:
        print ("Garis-garis akan berimpit, sehingga persamaan garis memiliki tak berhingga solusi.")
         # Menyiapkan data untuk plotting
        x_vals = np.linspace(-10, 10, 400)
        y_vals1 = (r_04 - p_04* x_vals) / q_04
        y_vals2 = (u_04 - s_04 * x_vals) / t_04

        # Plot garis pertama
        plt.plot(x_vals, y_vals1, label=f'{p_04}x + {q_04}y = {r_04}')

        # Plot garis kedua
        plt.plot(x_vals, y_vals2, label=f'{s_04}x + {t_04}y = {u_04}')

        # Plot titik potong
        plt.plot(x_04, y_04, 'ro')  # 'ro' means red color, circle marker
        plt.text(x_04, y_04, f'({x_04:.2f}, {y_04:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah persamaan garisnya')

        # Menampilkan plot
        plt.show()

    else:
        # Menghitung determinan untuk x dan y
        Dx_04 = r_04*t_04 - q_04*u_04
        Dy_04 = p_04*u_04 - r_04*s_04
        # Menemukan solusi untuk x dan y
        x_04 = Dx_04 /D_04
        y_04 = Dy_04 /D_04
        print(f"Titik potong dari dua garis adalah: x = {x_04}, y = {y_04}")
        # Menyiapkan data untuk plotting
        x_vals = np.linspace(-10, 10, 400)
        y_vals1 = (r_04 - p_04* x_vals) / q_04
        y_vals2 = (u_04 - s_04 * x_vals) / t_04

        # Plot garis pertama
        plt.plot(x_vals, y_vals1, label=f'{p_04}x + {q_04}y = {r_04}')

        # Plot garis kedua
        plt.plot(x_vals, y_vals2, label=f'{s_04}x + {t_04}y = {u_04}')

        # Plot titik potong
        plt.plot(x_04, y_04, 'ro')  # 'ro' means red color, circle marker
        plt.text(x_04, y_04, f'({x_04:.2f}, {y_04:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah persamaan garisnya')

        # Menampilkan plot
        plt.show()

else:
  print('Tidak ada solusi ')
# Out:
# Kasus berapakah yang akan dikerjakan? 3
# Garis pertama yang memenuhi persamaan berbentuk ax + by = c
# Koefisien dari x pada garis pertama adalah 2
# Koefisien dari y pada garis pertama adalah 3
# Konstanta dari garis pertama adalah 6
# Garis kedua yang memenuhi persamaan berbentuk dx + ey = f
# Koefisien dari x pada garis kedua adalah 3
# Koefisien dari y pada garis kedua adalah 5
# Konstanta dari garis kedua adalah 9
# Titik potong dari dua garis adalah: x = 3.0, y = 0.0

# %%
# SOLUSI KASUS 3 MENGGUNAKAN MATRIKS
# Memanggil numpy
import numpy as np
# Memanggil pyplot
import matplotlib.pyplot as plt

# Masukkan nilai koefisien dan konstanta
print("Garis pertama yang memenuhi persamaan berbentuk ax + by = c ")
p_04 = float(input("Koefisien dari x pada garis pertama adalah "))
q_04 = float(input("Koefisien dari y pada garis pertama adalah "))
r_04 = float(input("Konstanta dari garis pertama adalah "))

print("Garis kedua yang memenuhi persamaan berbentuk dx + ey = f ")
s_04 = float(input("Koefisien dari x pada garis kedua adalah "))
t_04 = float(input("Koefisien dari y pada garis kedua adalah "))
u_04 = float(input("Konstanta dari garis kedua adalah "))


def solve_linear_equations(p_04,q_04,r_04,s_04,t_04,u_04):
    # Membuat bentuk matriks dari koefisien
    P_04 = np.array([[p_04, q_04],
                  [s_04, t_04]])

    # Membuat bentuk matriks konstanta
    Q_04 = np.array([r_04, u_04])

    # Hitung determinan dari matriks M
    det_P_04 = np.linalg.det(P_04)

    if det_P_04 != 0:
        # Satu Solusi
        solution = np.linalg.solve(P_04, Q_04)
        result = f"Satu Solusi: x = {solution[0]}, y = {solution[1]}"
        plot_lines_and_solution(p_04,q_04,r_04,s_04,t_04,u_04,solution)
        return result
    else:
        # Memastikan sistem
        augmented_matrix_24 = np.array([[p_04, q_04, r_04],
                                     [s_04, t_04, u_04]])
        rank_P_04 = np.linalg.matrix_rank(P_04)
        rank_augmented_04 = np.linalg.matrix_rank(augmented_matrix_04)

        if rank_P_04 == rank_augmented_04:
            result = "Tak terhingga solusi"
            plot_lines_and_solution(p_04,q_04,r_04,s_04,t_04,u_04,None)
            return result
        else:
            result = "Tidak terdapat solusi"
            plot_lines_and_solution(p_04,q_04,r_04,s_04,t_04,u_04,None)
            return result_

def plot_lines_and_solution(p_04,q_04,r_04,s_04,t_04,u_04,solution):
    # Tentukan range nilai x
    x_values_04 = np.linspace(-10, 10, 400)

    # Hitung nilai y masing-masing persamaan
    y1_values_04 = (r_04 - p_04 * x_values_04) / q_04
    y2_values_04 = (u_04 - s_04 * x_values_04) / t_04

    plt.figure(figsize=(8, 6))

    # Plot garis pertama
    plt.plot(x_values_04, y1_values_04, label=f'{p_04}x + {q_04}y = {r_04}')

    # Plot garis kedua
    plt.plot(x_values_04, y2_values_04, label=f'{s_04}x + {t_04}y = {u_04}')

    # Jika ada solusi tunggal, plot titik potong
    if solution is not None:
        plt.plot(solution[0], solution[1], 'ro')  # Titik potong berwarna merah
        plt.annotate(f'({solution[0]:.2f}, {solution[1]:.2f})', xy=(solution[0], solution[1]), xytext=(solution[0] + 1, solution[1]))

    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Grafik Persamaan Linear')
    plt.show()


result = solve_linear_equations(p_04,q_04,r_04,s_04,t_04,u_04)
print(result)
print('=============================TERIMA KASIH==================================')
# Out:
# Garis pertama yang memenuhi persamaan berbentuk ax + by = c
# Koefisien dari x pada garis pertama adalah 1
# Koefisien dari y pada garis pertama adalah 3
# Konstanta dari garis pertama adalah 4
# Garis kedua yang memenuhi persamaan berbentuk dx + ey = f
# Koefisien dari x pada garis kedua adalah 3
# Koefisien dari y pada garis kedua adalah 4
# Konstanta dari garis kedua adalah 5
# Satu Solusi: x = -0.20000000000000018, y = 1.4000000000000001
# =============================TERIMA KASIH==================================

# %%
import numpy as np
import matplotlib.pyplot as plt

kasus = float(input("Kasus berapakah yang akan dikerjakan? "))

if kasus == 1:
    # Masukkan titik garis pertama (a,b) dan (c,d)
    p_04 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
    q_04 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
    r_04 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
    s_04 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

    # Masukkan titik garis kedua (e,f) dan (g,h)
    t_04 = float(input("Nilai x dari titik pertama dari garis kedua adalah "))
    u_04 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
    v_04 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
    w_04 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

    # Gradien garis pertama
    m1_04 = (s_04 - q_04) / (r_04 - p_04)
    # Gradien garis kedua
    m2_04 = (w_04 - u_04) / (v_04 - t_04)

    # Persamaan garis pertama adalah y=m1(x-a)+b => m1*x-m1*a+b
    # Persamaan garis kedua adalah y=m2(x-e)+f => m2*x-m2*e+f

    # Titik potong garis pertama terhadap sumbu y
    c1_04 = -m1_04 * p_04 + q_04
    # Titik potong garis kedua terhadap sumbu y garis kedua
    c2_04 = -m2_04 * t_04 + u_04

    print("Persamaan garis pertama adalah y={}x+{}".format(m1_04, c1_04))
    print("Persamaan garis kedua adalah y={}x+{}".format(m2_04, c2_04))

    if m1_04 == m2_04:
        # print("Kedua garis sejajar sehingga kemungkinan yang terjadi adalah tidak terdapat solusi atau terdapat tidak berhingga banyaknya solusi")
        if c1_04 == c2_04:
            print("Kedua garis akan berhimpitan sehingga terdapat tidak berhingga banyaknya solusi")
            x_04 = np.linspace(-9, 9, 100)
            plt.plot(x_04, m1_04 * (x_04 - p_04) + q_04, color='pink')
            plt.plot(x_04, m2_04 * (x_04 - t_04) + u_04, color='yellow')
            plt.show()
        else:
            print("Kedua garis tidak akan berpotongan, sehingga tidak akan terdapat solusi")
            x_04 = np.linspace(-10, 10, 100)
            plt.plot(x_04, m1_04 * (x_04 - p_04) + q_04, color='green')
            plt.plot(x_04, m2_04 * (x_04 - t_04) + u_04, color='red')
            plt.show()
    else:
        print("Terdapat satu titik potong")
        tp_x_04 = (-m2_04 * t_04 + u_04 + m1_04 * p_04 - q_04) / (m1_04 - m2_04)
        tp_y_04 = m1_04 * (tp_x_04 - p_04) + q_04
        print("Titik potong kedua garis yaitu ({},{})".format(tp_x_04, tp_y_04))

        x_04 = np.linspace(tp_x_04 - 10, tp_x_04 + 10, 100)
        plt.plot(x_04, m1_04 * (x_04 - p_04) + q_04, color='red')
        plt.plot(x_04, m2_04 * (x_04 - t_04) + u_04, color='green')
        plt.plot(tp_x_04, tp_y_04, color='black', marker='o', markersize=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.show()

elif kasus == 2:
    # Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (a,b)
    m1_04 = float(input("Gradien dari garis pertama adalah: "))
    p_04 = float(input("Nilai x dari titik yang dilewati oleh garis pertama adalah: "))
    q_04 = float(input("Nilai y dari titik yang dilewati oleh garis pertama adalah: "))

    # Masukkan nilai gradien persamaan garis kedua dan titik yang diketahui (c,d)
    m2_04 = float(input("Gradien dari garis kedua adalah: "))
    r_04 = float(input("Nilai x dari titik yang dilewati oleh garis kedua adalah: "))
    s_04 = float(input("Nilai y dari titik yang dilewati oleh garis kedua adalah: "))

    # Menghitung konstanta dari masing-masing persamaan garis
    c1_04 = -m1_04 * p_04 + q_04
    c2_04 = -m2_04 * r_04 + s_04

    # Memeriksa apakah kedua garis sejajar atau tidak
    if m1_04 == m2_04:
        # print("Kedua garis sejajar ")
        if c1_04 == c2_04:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Format garis
        x_04 = np.linspace(-10, 10, 400)
        y1_04 = m1_04 * (x_04 - p_04) + q_04
        y2_04 = m2_04 * (x_04 - r_04) + s_04
        plt.plot(x_04, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='red')
        plt.plot(x_04, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='pink')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
    else:
        # Menghitung titik potong dari kedua garis
        tp_x_04 = (c2_04 - c1_04) / (m1_04 - m2_04)
        tp_y_04= m1_04 * (x_intersect - p_04) + q_04
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x_04, tp_y_04))

        # Format garis
        x_04 = np.linspace(tp_x_04 - 10, tp_x_04 + 10, 400)
        y1_04 = m1_04 * (x_04 - p_04) + q_04
        y2_04 = m2_04 * (x_04 - r_04) + s_04
        plt.plot(x_04, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='red')
        plt.plot(x_04, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='blue')
        plt.scatter(tp_x_04, tp_y_04, color='green', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()

elif kasus == 3:
    # Masukkan nilai koefisien dan konstanta
    print("Garis pertama yang memenuhi persamaan berbentuk ax + by = c ")
    p_04 = float(input("Koefisien dari x pada garis pertama adalah "))
    q_04 = float(input("Koefisien dari y pada garis pertama adalah "))
    r_04 = float(input("Konstanta dari garis pertama adalah "))

    print("Garis kedua yang memenuhi persamaan berbentuk dx + ey = f ")
    s_04 = float(input("Koefisien dari x pada garis kedua adalah "))
    t_04 = float(input("Koefisien dari y pada garis kedua adalah "))
    u_04 = float(input("Konstanta dari garis kedua adalah "))
    # Menghitung determinan utama
    D_04 = p_04*t_04 - q_04*s_04

    if D_04 == 0:
        print ("Garis-garis akan berimpit, sehingga persamaan garis memiliki tak berhingga solusi.")
         # Menyiapkan data untuk plotting
        x_vals = np.linspace(-10, 10, 400)
        y_vals1 = (r_04 - p_04* x_vals) / q_04
        y_vals2 = (u_04 - s_04 * x_vals) / t_04

        # Plot garis pertama
        plt.plot(x_vals, y_vals1, label=f'{p_04}x + {q_04}y = {r_04}')

        # Plot garis kedua
        plt.plot(x_vals, y_vals2, label=f'{s_04}x + {t_04}y = {u_04}')

        # Plot titik potong
        plt.plot(x_04, y_04, 'ro')  # 'ro' means red color, circle marker
        plt.text(x_04, y_04, f'({x_04:.2f}, {y_04:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah persamaan garisnya')

        # Menampilkan plot
        plt.show()

    else:
        # Menghitung determinan untuk x dan y
        Dx_04 = r_04*t_04 - q_04*u_04
        Dy_04 = p_04*u_04 - r_04*s_04
        # Menemukan solusi untuk x dan y
        x_04 = Dx_04 /D_04
        y_04 = Dy_04 /D_04
        print(f"Titik potong dari dua garis adalah: x = {x_04}, y = {y_04}")
        # Menyiapkan data untuk plotting
        x_vals = np.linspace(-10, 10, 400)
        y_vals1 = (r_04 - p_04* x_vals) / q_04
        y_vals2 = (u_04 - s_04 * x_vals) / t_04

        # Plot garis pertama
        plt.plot(x_vals, y_vals1, label=f'{p_04}x + {q_04}y = {r_04}')

        # Plot garis kedua
        plt.plot(x_vals, y_vals2, label=f'{s_04}x + {t_04}y = {u_04}')

        # Plot titik potong
        plt.plot(x_04, y_04, 'ro')  # 'ro' means red color, circle marker
        plt.text(x_04, y_04, f'({x_04:.2f}, {y_04:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah persamaan garisnya')

        # Menampilkan plot
        plt.show()

else:
  print('Tidak ada solusi ')
# Out:
# Kasus berapakah yang akan dikerjakan? 2
# Gradien dari garis pertama adalah: 5
# Nilai x dari titik yang dilewati oleh garis pertama adalah: 1
# Nilai y dari titik yang dilewati oleh garis pertama adalah: 0
# Gradien dari garis kedua adalah: 5
# Nilai x dari titik yang dilewati oleh garis kedua adalah: 0
# Nilai y dari titik yang dilewati oleh garis kedua adalah: -1
# Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.

# %%
import numpy as np
import matplotlib.pyplot as plt

kasus = float(input("Kasus berapakah yang akan dikerjakan? "))

if kasus == 1:
    # Masukkan titik garis pertama (a,b) dan (c,d)
    p_04 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
    q_04 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
    r_04 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
    s_04 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

    # Masukkan titik garis kedua (e,f) dan (g,h)
    t_04 = float(input("Nilai x dari titik pertama dari garis kedua adalah "))
    u_04 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
    v_04 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
    w_04 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

    # Gradien garis pertama
    m1_04 = (s_04 - q_04) / (r_04 - p_04)
    # Gradien garis kedua
    m2_04 = (w_04 - u_04) / (v_04 - t_04)

    # Persamaan garis pertama adalah y=m1(x-a)+b => m1*x-m1*a+b
    # Persamaan garis kedua adalah y=m2(x-e)+f => m2*x-m2*e+f

    # Titik potong garis pertama terhadap sumbu y
    c1_04 = -m1_04 * p_04 + q_04
    # Titik potong garis kedua terhadap sumbu y garis kedua
    c2_04 = -m2_04 * t_04 + u_04

    print("Persamaan garis pertama adalah y={}x+{}".format(m1_04, c1_04))
    print("Persamaan garis kedua adalah y={}x+{}".format(m2_04, c2_04))

    if m1_04 == m2_04:
        # print("Kedua garis sejajar sehingga kemungkinan yang terjadi adalah tidak terdapat solusi atau terdapat tidak berhingga banyaknya solusi")
        if c1_04 == c2_04:
            print("Kedua garis akan berhimpitan sehingga terdapat tidak berhingga banyaknya solusi")
            x_04 = np.linspace(-9, 9, 100)
            plt.plot(x_04, m1_04 * (x_04 - p_04) + q_04, color='pink')
            plt.plot(x_04, m2_04 * (x_04 - t_04) + u_04, color='yellow')
            plt.show()
        else:
            print("Kedua garis tidak akan berpotongan, sehingga tidak akan terdapat solusi")
            x_04 = np.linspace(-10, 10, 100)
            plt.plot(x_04, m1_04 * (x_04 - p_04) + q_04, color='green')
            plt.plot(x_04, m2_04 * (x_04 - t_04) + u_04, color='red')
            plt.show()
    else:
        print("Terdapat satu titik potong")
        tp_x_04 = (-m2_04 * t_04 + u_04 + m1_04 * p_04 - q_04) / (m1_04 - m2_04)
        tp_y_04 = m1_04 * (tp_x_04 - p_04) + q_04
        print("Titik potong kedua garis yaitu ({},{})".format(tp_x_04, tp_y_04))

        x_04 = np.linspace(tp_x_04 - 10, tp_x_04 + 10, 100)
        plt.plot(x_04, m1_04 * (x_04 - p_04) + q_04, color='red')
        plt.plot(x_04, m2_04 * (x_04 - t_04) + u_04, color='green')
        plt.plot(tp_x_04, tp_y_04, color='black', marker='o', markersize=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.show()

elif kasus == 2:
    # Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (a,b)
    m1_04 = float(input("Gradien dari garis pertama adalah: "))
    p_04 = float(input("Nilai x dari titik yang dilewati oleh garis pertama adalah: "))
    q_04 = float(input("Nilai y dari titik yang dilewati oleh garis pertama adalah: "))

    # Masukkan nilai gradien persamaan garis kedua dan titik yang diketahui (c,d)
    m2_04 = float(input("Gradien dari garis kedua adalah: "))
    r_04 = float(input("Nilai x dari titik yang dilewati oleh garis kedua adalah: "))
    s_04 = float(input("Nilai y dari titik yang dilewati oleh garis kedua adalah: "))

    # Menghitung konstanta dari masing-masing persamaan garis
    c1_04 = -m1_04 * p_04 + q_04
    c2_04 = -m2_04 * r_04 + s_04

    # Memeriksa apakah kedua garis sejajar atau tidak
    if m1_04 == m2_04:
        # print("Kedua garis sejajar ")
        if c1_04 == c2_04:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Format garis
        x_04 = np.linspace(-10, 10, 400)
        y1_04 = m1_04 * (x_04 - p_04) + q_04
        y2_04 = m2_04 * (x_04 - r_04) + s_04
        plt.plot(x_04, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='red')
        plt.plot(x_04, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='pink')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
    else:
        # Menghitung titik potong dari kedua garis
        tp_x_04 = (c2_04 - c1_04) / (m1_04 - m2_04)
        tp_y_04= m1_04 * (x_intersect - p_04) + q_04
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x_04, tp_y_04))

        # Format garis
        x_04 = np.linspace(tp_x_04 - 10, tp_x_04 + 10, 400)
        y1_04 = m1_04 * (x_04 - p_04) + q_04
        y2_04 = m2_04 * (x_04 - r_04) + s_04
        plt.plot(x_04, y1_04, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_04, p_04, q_04), color='purple')
        plt.plot(x_04, y2_04, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_04, r_04, s_04), color='blue')
        plt.scatter(tp_x_04, tp_y_04, color='green', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()

elif kasus == 3:
    # Masukkan nilai koefisien dan konstanta
    print("Garis pertama yang memenuhi persamaan berbentuk ax + by = c ")
    p_04 = float(input("Koefisien dari x pada garis pertama adalah "))
    q_04 = float(input("Koefisien dari y pada garis pertama adalah "))
    r_04 = float(input("Konstanta dari garis pertama adalah "))

    print("Garis kedua yang memenuhi persamaan berbentuk dx + ey = f ")
    s_04 = float(input("Koefisien dari x pada garis kedua adalah "))
    t_04 = float(input("Koefisien dari y pada garis kedua adalah "))
    u_04 = float(input("Konstanta dari garis kedua adalah "))
    # Menghitung determinan utama
    D_04 = p_04*t_04 - q_04*s_04

    if D_04 == 0:
        print ("Garis-garis akan berimpit, sehingga persamaan garis memiliki tak berhingga solusi.")
         # Menyiapkan data untuk plotting
        x_vals = np.linspace(-10, 10, 400)
        y_vals1 = (r_04 - p_04* x_vals) / q_04
        y_vals2 = (u_04 - s_04 * x_vals) / t_04

        # Plot garis pertama
        plt.plot(x_vals, y_vals1, label=f'{p_04}x + {q_04}y = {r_04}')

        # Plot garis kedua
        plt.plot(x_vals, y_vals2, label=f'{s_04}x + {t_04}y = {u_04}')

        # Plot titik potong
        plt.plot(x_04, y_04, 'ro')  # 'ro' means red color, circle marker
        plt.text(x_04, y_04, f'({x_04:.2f}, {y_04:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah persamaan garisnya')

        # Menampilkan plot
        plt.show()

    else:
        # Menghitung determinan untuk x dan y
        Dx_04 = r_04*t_04 - q_04*u_04
        Dy_04 = p_04*u_04 - r_04*s_04
        # Menemukan solusi untuk x dan y
        x_04 = Dx_04 /D_04
        y_04 = Dy_04 /D_04
        print(f"Titik potong dari dua garis adalah: x = {x_04}, y = {y_04}")
        # Menyiapkan data untuk plotting
        x_vals = np.linspace(-10, 10, 400)
        y_vals1 = (r_04 - p_04* x_vals) / q_04
        y_vals2 = (u_04 - s_04 * x_vals) / t_04

        # Plot garis pertama
        plt.plot(x_vals, y_vals1, label=f'{p_04}x + {q_04}y = {r_04}')

        # Plot garis kedua
        plt.plot(x_vals, y_vals2, label=f'{s_04}x + {t_04}y = {u_04}')

        # Plot titik potong
        plt.plot(x_04, y_04, 'ro')  # 'ro' means red color, circle marker
        plt.text(x_04, y_04, f'({x_04:.2f}, {y_04:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah persamaan garisnya')

        # Menampilkan plot
        plt.show()

else:
  print('Tidak ada solusi ')
# Out:
# Kasus berapakah yang akan dikerjakan? 1
# Nilai x dari titik pertama dari garis pertama adalah 2
# Nilai y dari titik pertama dari garis pertama adalah 4
# Nilai x dari titik kedua dari garis pertama adalah 3
# Nilai y dari titik kedua dari garis pertama adalah 6
# Nilai x dari titik pertama dari garis kedua adalah -1
# Nilai y dari titik pertama dari garis kedua adalah 1
# Nilai x dari titik kedua dari garis kedua adalah 1
# Nilai y dari titik kedua dari garis kedua adalah 1
# Persamaan garis pertama adalah y=2.0x+0.0
# Persamaan garis kedua adalah y=0.0x+1.0
# Terdapat satu titik potong
# Titik potong kedua garis yaitu (0.5,1.0)

# %%
6
