# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
nama = 'bakmie ayam'
pilihan = 'ayam biasa, ayam spesial, ayam bakso'
saos = 'manis kecap, saos kecap'
harga = 'dimulai dari 1500 sampai 30000'
print(nama + 'memiliki pilihan' + pilihan + 'saos' + saos + 'dengan harga' + harga + 'jangan lupa cobain ya')
# Out:
# bakmie ayammemiliki pilihanayam biasa, ayam spesial, ayam baksosaosmanis kecap, saos kecapdengan hargadimulai dari 1500 sampai 30000jangan lupa cobain ya

# %%
nama = 'Aditya'
olahraga = 'voli'
cabang = 'PORJAR'
sekolah = 'SMA N 1 Petang'
print(f'{nama} mengikuti {olahraga} pada {cabang} mewakili {sekolah}.')
# Out:
# Aditya mengikuti voli pada PORJAR mewakili SMA N 1 Petang.

# %%
kegiatan = 'pelatihan FIGMA 2024'
print(kegiatan[5:-4])
# Out:
# ihan FIGMA

# %%
print(kegiatan[1:-2])
# Out:
# elatihan FIGMA 20

# %%
print(kegiatan[1:])
# Out:
# elatihan FIGMA 2024

# %%
print(kegiatan[3:-4:2])
# Out:
# aia IM

# %%
print(kegiatan[2:-3:5])
# Out:
# laG

# %%
judul = 'keindahan sunset di pantai kedungu'
print(len(judul))
# Out:
# 34

# %%
judul.upper()
# Out:
# 'KEINDAHAN SUNSET DI PANTAI KEDUNGU'

# %%
judul.lower()
# Out:
# 'keindahan sunset di pantai kedungu'

# %%
judul.find('kedungu')
# Out:
# 27

# %%
judul.find('Pantai')
# Out:
# -1

# %%
judul.replace('kedungu', 'tabanan')
# Out:
# 'keindahan sunset di pantai tabanan'

# %%
judul.replace('Kedungu', 'tabanan')
# Out:
# 'keindahan sunset di pantai kedungu'

# %%
print('keindahan' in judul)
# Out:
# True

# %%
print('Sunset' in judul)
# Out:
# False

# %%
print(4+6)
print(4-6)
print(4*6)
print(9/4)
print(9//4)
print(9%4)
print(4**6)
x=5
x+=2
print(x)
x-=3
print(x)
x*=4
print(x)
# Out:
# 10
# -2
# 24
# 2.25
# 2
# 1
# 4096
# 7
# 4
# 16

# %%
x = 7>6
print(x)
x = 6<7
print(x)
x = 7 >= 6
print(x)
x = 6 <= 7
print(x)
x = 6 == 6
print(x)
x = 2 != 5
print(x)
# Out:
# True
# True
# True
# True
# True
# True

# %%
x = 7<6
print(x)
x = 6>7
print(x)
x = 7 <= 6
print(x)
x = 6 >= 7
print(x)
x = 6 == 5
print(x)
x = 2 != 2
print(x)
# Out:
# False
# False
# False
# False
# False
# False

# %%
bola_kuning_diva = 20
bola_merah_mita = 25
bola_putih_rosa = 35
bola_hijau_ratih = 15
bola_hitam_pira = 10
print(bola_merah_mita > 15 and bola_putih_rosa > 20)
# Out:
# True

# %%
print(bola_hitam_pira < 9 and bola_kuning_diva < 15)
# Out:
# False

# %%
print(bola_hijau_ratih > 10 and bola_kuning_diva > 15)
# Out:
# True

# %%
print(bola_putih_rosa < 20 and bola_hitam_pira > 10)
# Out:
# False

# %%
print(bola_merah_mita > 15 and bola_hitam_pira > 5)
# Out:
# True

# %%
print(5+8)
print(8-5)
print(5*8)
print(8/5)
print(8//5)
print(5%8)
print(8**5)
x=4
x+=5
print(x)
x-=7
print(x)
x*=6
print(x)
# Out:
# 13
# 3
# 40
# 1.6
# 1
# 5
# 32768
# 9
# 2
# 12

# %%
nama = 'udara pagi hari sangat cerah'
print(nama[4:-2:5])
# Out:
# aiige

# %%
print(nama[2:-5])
# Out:
# ara pagi hari sangat

# %%
print(nama[5:-1:2])
# Out:
#  aihr agtcr

# %%
print(nama[4:-3:2])
# Out:
# apg aisna e

# %%
print(nama[1:-4:3])
# Out:
# daa rsg

# %%
print(nama[1:-2:3])
# Out:
# daa rsg r
